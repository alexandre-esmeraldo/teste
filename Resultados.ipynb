# %% [markdown]
# # ==================== Calcula Resultado Anual ====================

# %%
from pandas import Series
import pandas as pd
from datetime import date, datetime
from IPython.display import display, Markdown
import matplotlib as mat
pd.__version__
# Out:
# '2.0.3'

# %%
import time
time.asctime( time.localtime(time.time()) )
# Out:
# 'Wed Jul 16 13:02:30 2025'

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
# Setando opção do Pandas para mostrar todas as linhas
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## === ANO ===

# %%
ano = 2025

# %%
# Setando definição de cores
def color_negative_red(val):
    color = 'red' if val < 0 else 'green'
    return 'color: %s' % color

# %%
import subprocess
p = subprocess.call(["powershell.exe", "copy 'Gerenciador de Ações.v6.xlsx' tempfile.xlsx"])

# %%
# Leitura de planilha Excel
ws = pd.read_excel('tempfile.xlsx', sheet_name="CÁLCULOS (3)", header=None)
# dt_acerto = ws[8][12]
dt_acerto = ws[8][12][19:29]
pc_liq_acerto = str(round(ws[5][13] * 100, 2)).replace('.', ',')
vr_liq_acerto = str(round(ws[5][12], 2)).replace('.', ',')
qt_acoes_acerto = str(ws[3][9])
vr_acao_acerto = str(ws[3][10])

# %%
import os
os.remove('tempfile.xlsx')

# %%
print([dt_acerto, pc_liq_acerto, vr_liq_acerto, qt_acoes_acerto, vr_acao_acerto])
# Out:
# ['13/06/2023', '3,12', '2945,56', '14300', '6.8']

# %%
# Setando variáveis

valor_acerto = 0
arquivo_csv = 'arquivos/relatorioOperacoes' + str(ano) + '.csv'

# Data da Operação, Tipo Operação, Característica, Ativo, Corretora, Qtde, Preço (R$), Custo Médio (R$), %, Resultado (R$)
matrix_acerto = [['01/07/2020', 'acerto', 'acerto',   'acerto', 'acerto',  '0.00', '0.00', 0,  '-20,79', '0,00'      ],
                 ['01/09/2020', 'acerto', 'acerto',   'acerto', 'acerto',  '0.00', '0.00', 0,  '2,66',   '0,00'      ],
                 ['02/02/2021', 'acerto', 'acerto',   'acerto', 'acerto',  '0.00', '0.00', 0,  '-1,84',  '0,00'      ],
                 ['17/06/2021', 'acerto', 'acerto',   'acerto', 'acerto',  '0.00', '0.00', 0,  '1,75',   '0,00'      ],
                 ['25/09/2024', 'acerto', 'acerto',   'acerto', 'acerto',  '0.00', '0.00', 0,  '2,06',   '0,00'      ],
                 ['18/10/2024', 'Dividendos', 'acerto', 'EVEN3', 'acerto', 8900 , '0.00', 0,  '0,00', '3560,00'],
                 ['28/09/2023', 'PAGMTO FRACOES', 'acerto', 'BRPR3', 'acerto', 0 , '0.00', 0,  '0,00', '427,41'],
                 ['14/09/2023', 'Restituição de Capital', 'acerto', 'BRPR3 ', 'acerto', 389 , '0.00', 0,  '0,00', '24527,73'],
                 ['22/03/2023', 'PG.JUR.CAP.PROP', 'acerto', 'VALE3', 'acerto', 1100 , '0.00', 0,  '0,00', '273,03'],
                 ['20/07/2022', 'Dividendos', 'acerto', 'PETR4', 'acerto', 3400 , '0.00', 0,  '0,00', '6316,33'],
                 ['20/06/2022', 'Dividendos', 'acerto', 'PETR4', 'acerto', 3400 , '0.00', 0,  '0,00', '4853,73'],
                 ['20/06/2022', 'PG.JUR.CAP.PROP', 'acerto', 'PETR4', 'acerto', 3400 , '0.00', 0,  '0,00', '1243,21'],
                 ['05/04/2022', 'Dividendos', 'acerto', 'PTBL3', 'acerto', 16000, '0.00', 0,  '0,00', '395,94'],
                 ['31/05/2021', 'Dividendos', 'acerto', 'USIM5', 'acerto', 6100 , '0.00', 0,  '0,00', '804,68'],
                 ['30/04/2021', 'Dividendos', 'acerto', 'UNIP6', 'acerto', 1700 , '0.00', 0,  '0,00', '284,95'],
                 ['30/04/2021', 'Dividendos', 'acerto', 'UNIP6', 'acerto', 1700 , '0.00', 0,  '0,00', '1791,96'],
                 ['18/11/2020', 'Dividendos', 'acerto', 'GGBR4', 'acerto', 5700 , '0.00', 0,  '0,00', '684,00'],
                 ['20/08/2020', 'PG.JUR.CAP.PROP', 'acerto', 'BIDI4', 'acerto', 7500 , '0.00', 0,  '0,00', '67,27'],
                 ['01/07/2020', 'Dividendos', 'acerto', 'ITSA4', 'acerto', 1100 , '0.00', 0,  '0,00', '22,00'],
                 ['14/06/2019', 'PG.JUR.CAP.PROP', 'acerto', 'BPAN4', 'acerto', 2000 , '0.00', 0,  '0,00', '129,11'],
                 ['09/05/2018', 'Dividendos', 'acerto', 'SUZB3', 'acerto', 500 , '0.00', 0,  '0,00', '96,11'],
                 ['09/11/2017', 'PAGMTO FRACOES', 'acerto', 'PPLA11', 'acerto', 0 , '0.00', 0,  '0,00', '0,38    '],
                 ['02/09/2016', 'Dividendos', 'acerto', 'GGBR4', 'acerto', 2000 , '0.00', 0,  '0,00', '60,00'],
                 [dt_acerto, 'Venda (planilha)', 'acerto', 'acerto', 'acerto', qt_acoes_acerto, vr_acao_acerto, 0, pc_liq_acerto, vr_liq_acerto]
                ]

# %%
# Usando o método read_csv
df = pd.read_csv(arquivo_csv, delimiter=";", encoding='ansi', decimal=",")

# %%
del df["Data da Operação"]
df = df.rename(columns = {"Unnamed: 0" : "Data da Operação",
                          "Lucro/Perda (R$)" : "Resultado (R$)"})

# %%
#Substitui NaN por "-"
df = df.fillna("-")

# %%
# Copia coluna "Resultado (R$)" para novo Dataframe dfTemp
dfTemp = df["Resultado (R$)"]
dfFinal = df

# %%
# Exclui coluna "Resultado (R$)" do Dataframe dfFinal
del dfFinal["Resultado (R$)"]

# %%
# Copia índices para exclusão do dfTemp
index = df[df['Ativo'] != '-'].index
# Exclui linhas nulas do dfTemp
dfTemp.drop(index, inplace=True)

# %%
# Reorganiza índice dfTemp
dfTemp.index = pd.Categorical(dfTemp.index).codes

# %%
# Copia índices para exclusão do dfFinal
index = df[df['Ativo'] == '-'].index
# Exclui linhas nulas do dfFinal
dfFinal.drop(index, inplace=True)

# %%
# Reorganiza índice dfFinal
dfFinal.index = pd.Categorical(dfFinal.index).codes

# %%
dfFinal[dfTemp.name] = dfTemp

# %%
# Conversão da coluna Data de Operação para tipo Data
dfFinal['Data da Operação'] = pd.to_datetime(dfFinal['Data da Operação'], format='%d/%m/%Y')

# %% [markdown]
# ## Aplica acertos

# %%
start_date= datetime.strptime(f'{ano}-01-01', '%Y-%m-%d')
end_date = datetime.strptime(f'{ano}-12-31', '%Y-%m-%d')

df_acerto = pd.DataFrame(matrix_acerto, columns=dfFinal.columns)
df_acerto['Data da Operação'] = pd.to_datetime(df_acerto['Data da Operação'], format='%d/%m/%Y')
mask = (df_acerto['Data da Operação'] >= start_date) & (df_acerto['Data da Operação'] <= end_date)
df_acerto = df_acerto.loc[mask]

df = pd.concat([dfFinal, df_acerto], ignore_index=True)

# %%
dfFinal = df.sort_values(['Data da Operação', 'Tipo Operação'], ascending=[True, False])

# %%
# Ajustando caracter de decimal e milhar em "Resultado (R$)", e conversão para float
dfFinal['Resultado (R$)'] = [x.replace('.','') for x in dfFinal['Resultado (R$)']]
dfFinal['Resultado (R$)'] = [x.replace(',','.') for x in dfFinal['Resultado (R$)']]
dfFinal['Resultado (R$)'] = dfFinal['Resultado (R$)'].astype(float)

# %%
# Removendo sinal de % para cálculos, e conversão para float
dfFinal['%'] = [x.replace(' %','') for x in dfFinal['%']]
dfFinal['%'] = [x.replace(',','.') for x in dfFinal['%']]
dfFinal['%'] = dfFinal['%'].astype(float)

# %%
dfFinal = dfFinal.drop(['Característica', 'Corretora'], axis=1)

# %%
dfFinal['Qtde'] = dfFinal['Qtde'].astype(str)
dfFinal['Qtde'] = [x.replace('.','') for x in dfFinal['Qtde']]
dfFinal['Qtde'] = dfFinal['Qtde'].astype(int)

# %%
dfFinal.iloc[-1].index
# Out:
# Index(['Data da Operação', 'Tipo Operação', 'Ativo', 'Qtde', 'Preço (R$)',
#        'Custo Médio (R$)', '%', 'Resultado (R$)'],
#       dtype='object')

# %%
# Excluir linha de acerto da planilha caso o valor já esteja lançado.
if dfFinal.iloc[-1]['Resultado (R$)'] == dfFinal.iloc[-2]['Resultado (R$)']:
    dfFinal=dfFinal.drop(dfFinal.index[-1])

# %%
dfFinal['Preço (R$)'] = dfFinal['Preço (R$)'].astype(float)

# %%
# Calcula vr_compra
vr_compra_bruto = dfFinal['Qtde'] * dfFinal['Preço (R$)']

# %%
emolumentos = 325 / 1000000
corretagem = 49 / 10
vr_compra = vr_compra_bruto + corretagem + (vr_compra_bruto * emolumentos)

# %%
dfFinal['Valor Compra'] = vr_compra

# %%
# dfFinal.style.applymap(color_negative_red, subset=['%','Lucro/Perda (R$)'])

# %%
# Cria Dataframe com apenas Porcentagem e Lucro/Perda (R$)
df_sum = dfFinal[['%', 'Resultado (R$)']].copy()

# %%
df_sum = df_sum.rename(columns = {"%" : "Porcentagem"})

# %%
# Agrupa por mês totalizando o lucro/Prejuízo
df_sum_lucro_perda = dfFinal.groupby(dfFinal['Data da Operação']
                                     .dt.strftime('%B'))['Resultado (R$)'].sum()

# %% [markdown]
# ## Totaliza lucros e prejuízos

# %%
# Totaliza lucros
df_lucros = dfFinal.loc[dfFinal['Resultado (R$)'] > 0] \
                   .groupby(dfFinal['Data da Operação']
                   .dt.strftime('%B'))['Resultado (R$)']
df_sum_lucros = df_lucros.sum()
df_qt_lucros  = df_lucros.count()

# Totaliza Prejuízos
df_perdas = dfFinal.loc[dfFinal['Resultado (R$)'] < 0] \
                   .groupby(dfFinal['Data da Operação']
                   .dt.strftime('%B'))['Resultado (R$)']
df_sum_perdas = df_perdas.sum()
df_qt_perdas  = df_perdas.count()

# %%
# Agrupa por mês totalizando a Porcentagem
df_sum_porcentagem = dfFinal.groupby(dfFinal['Data da Operação']
                                     .dt.strftime('%B'))['%'].sum()

# %%
dfFinal_teste = dfFinal.groupby(['Data da Operação', 'Tipo Operação']).sum(['Resultado (R$)', 'Valor Compra'])
dfFinal_teste.reset_index(drop=False, inplace=True)

# %%
# del dfFinal_teste['Preço (R$)']
del dfFinal_teste['%']
dfFinal_teste['%'] = (dfFinal_teste['Resultado (R$)'] * 100) / dfFinal_teste['Valor Compra']

# %%
dfFinal_teste['Data da Operação'] = pd.to_datetime(dfFinal_teste['Data da Operação'], format='%d/%m/%Y')
df_sum_porcentagem_teste = dfFinal_teste.groupby(dfFinal_teste['Data da Operação']
                                     .dt.strftime('%B'))['%'].sum()

# %%
array_meses = [4,8,12,2,1,7,6,3,5,11,10,9]
meses = []
if date.today().year == ano:
    for x in array_meses:
        if x <= date.today().month:
            meses.append(x)
else:
    meses = array_meses

# %%
# corrige lista de meses se mês atual não tiver operações
if len(meses) > len(df_sum_lucro_perda):
    meses.remove(max(meses))

# %%
# Cria DataFrame
df_tot_mes = pd.DataFrame({'mes':meses
                         ,'Mês':df_sum_lucro_perda.index.values
                         ,'Resultado (R$)':df_sum_lucro_perda
                         ,'Porcentagem':df_sum_porcentagem
                         ,'Total Lucros':df_sum_lucros
                         ,'Total Perdas':df_sum_perdas
                         ,'Qt Lucros':df_qt_lucros
                         ,'Qt Perdas':df_qt_perdas
                          }).set_index('mes')

# %%
df_tot_mes['Total Lucros'] = df_tot_mes['Total Lucros'].fillna(0.00)
df_tot_mes['Total Perdas'] = df_tot_mes['Total Perdas'].fillna(0.00)
df_tot_mes['Qt Lucros'] = df_tot_mes['Qt Lucros'].fillna(0).astype(int)
df_tot_mes['Qt Perdas'] = df_tot_mes['Qt Perdas'].fillna(0).astype(int)

# %%
df_tot_mes.sort_index(inplace=True)

# %%
# Setando separador de milhar
pd.options.display.float_format = '{:,.2f}'.format

# %%
# Calculando total do ano
resultado = round(df_sum['Resultado (R$)'].sum(), 2)
porcentagem = round(df_sum['Porcentagem'].sum(), 2)
total_lucros = round(df_tot_mes['Total Lucros'].sum(), 2)
total_perdas = round(df_tot_mes['Total Perdas'].sum(), 2)
qt_lucros = round(df_tot_mes['Qt Lucros'].sum(), 2)
qt_perdas = round(df_tot_mes['Qt Perdas'].sum(), 2)
resultado_txt = 'Lucro: ' if resultado >= 0 else 'Prejuízo...: '
porcentagem_txt = '> Porcentagem: '
# Markdown(f'{porcentagem_txt}**{porcentagem}%**<br>{resultado_txt}**R${resultado}**')

# %%
# Adicionando Total do Ano
df_tot_mes.loc[len(df_tot_mes) + 1] = ['Ano', resultado, porcentagem, total_lucros, total_perdas, qt_lucros, qt_perdas]
df_tot_mes.rename(index={len(df_tot_mes) : 'Total'}, inplace=True)

# %%
# df_tot_mes.style.applymap(color_negative_red, subset=['Lucro/Perda (R$)','Porcentagem'])
# df_tot_mes

# %%
df_tot_mes_format = df_tot_mes.copy()
df_tot_mes_format["Porcentagem"] = df_tot_mes_format["Porcentagem"] * 0.01
df_tot_mes_format = df_tot_mes_format.style.applymap(color_negative_red, subset=['Resultado (R$)','Porcentagem','Total Lucros','Total Perdas'])
# df_tot_mes_format.format(precision=2)
df_tot_mes_format = df_tot_mes_format.format(
    {
    "Resultado (R$)": "{:,.2f}".format,
    "Porcentagem": "{:,.2%}".format,
    "Total Lucros": "{:,.2f}".format,
    "Total Perdas": "{:,.2f}".format
})

# %% [markdown]
# ## Detalhamento

# %%
dfFinal['Qtde'] = dfFinal.loc[:, 'Qtde'].astype(int).map('{:,}'.format)
dfFinal["%"] = dfFinal["%"].apply(lambda x: x * 0.01)
dfFinal["%"] = dfFinal["%"].map('{:.2%}'.format)
dfFinal
# Out:
#     Data da Operação                                     Tipo Operação  \
# 0         2025-01-03                                            Compra
# 1         2025-01-06                                             Venda
# 2         2025-01-07                                            Compra
# 4         2025-01-08                                             Venda
# 3         2025-01-08                                            Compra
# 5         2025-01-09                                             Venda
# 6         2025-01-09                                            Compra
# 7         2025-01-10                                             Venda
# 8         2025-01-13                                            Compra
# 10        2025-01-14                                             Venda
# 9         2025-01-14                                            Compra
# 11        2025-01-15                                             Venda
# 12        2025-01-15                                            Compra
# 14        2025-01-16                                             Venda
# 13        2025-01-16                                            Compra
# 15        2025-01-17                                             Venda
# 16        2025-01-17                                            Compra
# 18        2025-01-20                                             Venda
# 17        2025-01-20                                            Compra
# 19        2025-01-21                                             Venda
# 20        2025-01-21                                            Compra
# 22        2025-01-22                                             Venda
# 21        2025-01-22                                            Compra
# 23        2025-01-23                                             Venda
# 24        2025-01-23                                            Compra
# 25        2025-01-24                                             Venda
# 26        2025-01-24                                            Compra
# 28        2025-01-27                                             Venda
# 27        2025-01-27                                            Compra
# 29        2025-01-28                                             Venda
# 30        2025-01-28                                            Compra
# 31        2025-01-29                                             Venda
# 32        2025-01-30                                            Compra
# 34        2025-01-31                                             Venda
# 33        2025-01-31                                            Compra
# 36        2025-02-03                                             Venda
# 35        2025-02-03                                            Compra
# 37        2025-02-04                                             Venda
# 38        2025-02-05                                            Compra
# 40        2025-02-06                                             Venda
# 39        2025-02-06                                            Compra
# 41        2025-02-07                                             Venda
# 42        2025-02-07                                            Compra
# 44        2025-02-10                                             Venda
# 43        2025-02-10                                            Compra
# 45        2025-02-11                                             Venda
# 46        2025-02-11                                            Compra
# 48        2025-02-12                                             Venda
# 47        2025-02-12                                            Compra
# 49        2025-02-13                                             Venda
# 225       2025-06-23                                             Venda
# 226       2025-06-23                                            Compra
# 227       2025-06-24                                             Venda
# 228       2025-06-25                                            Compra
# 230       2025-06-26                                             Venda
# 229       2025-06-26                                            Compra
# 231       2025-06-27                                             Venda
# 232       2025-06-27                                            Compra
# 234       2025-06-30                                             Venda
# 233       2025-06-30                                            Compra
# 235       2025-07-01                                             Venda
# 236       2025-07-01                                            Compra
# 238       2025-07-02                                             Venda
# 237       2025-07-02                                            Compra
# 239       2025-07-03                                             Venda
# 240       2025-07-03                                            Compra
# 241       2025-07-04                                             Venda
# 242       2025-07-04                                            Compra
# 243       2025-07-07                                             Venda
# 244       2025-07-07                                            Compra
# 246       2025-07-08                                             Venda
# 245       2025-07-08                                            Compra
# 247       2025-07-09                                             Venda
# 248       2025-07-09                                            Compra
# 249       2025-07-10                                             Venda
# 250       2025-07-10                                             Venda
# 251       2025-07-10                                            Compra
# 253       2025-07-11                                             Venda
# 254       2025-07-11                                             Venda
# 252       2025-07-11                                            Compra
# 255       2025-07-14                                             Venda
# 256       2025-07-14                                            Compra
# 258       2025-07-15                                             Venda
# 257       2025-07-15                                            Compra
#
#       Ativo     Qtde  Preço (R$) Custo Médio (R$)        %  Resultado (R$)  \
# 0     RCSL3   10,000        5.40             0.00    0.00%            0.00
# 1     RCSL3   10,000        5.65             5.40    4.75%        2,566.82
# 2     RCSL3   12,700        4.48             0.00    0.00%            0.00
# 4     RCSL3   12,700        4.33             4.48   -3.18%       -1,811.60
# 3     ONCO3   26,000        2.11             0.00    0.00%            0.00
# 5     ONCO3   26,000        2.13             2.11    1.36%          746.85
# 6     RCSL3   11,800        4.62             0.00    0.00%            0.00
# 7     RCSL3   11,800        4.76             4.62    3.18%        1,736.75
# 8     RCSL3    4,200        4.66             0.00    0.00%            0.00
# 10    RCSL3    4,200        4.80             4.66    3.15%          618.06
# 9     ONCO3   26,900        2.06             0.00    0.00%            0.00
# 11    ONCO3   26,900        2.08             2.06    1.39%          773.50
# 12    RCSL3   11,500        4.83             0.00    0.00%            0.00
# 14    RCSL3   11,500        5.02             4.83    4.07%        2,265.98
# 13    GFSA3   41,300        1.32             0.00    0.00%            0.00
# 15    GFSA3   41,300        1.35             1.32    2.96%        1,618.79
# 16    RCSL3   11,800        4.70             0.00    0.00%            0.00
# 18    RCSL3   11,800        4.84             4.70    3.12%        1,736.19
# 17    GOLL4   34,600        1.70             0.00    0.00%            0.00
# 19    GOLL4   34,600        1.65             1.70   -2.41%       -1,418.87
# 20    RCSL3   13,000        4.61             0.00    0.00%            0.00
# 22    RCSL3   13,000        4.66             4.61    1.24%          743.80
# 21    AZEV4   51,000        1.20             0.00    0.00%            0.00
# 23    AZEV4   51,000        1.13             1.20   -5.05%       -3,095.80
# 24   NFLX34      500      116.33             0.00    0.00%            0.00
# 25   NFLX34      500      114.09           116.33   -1.92%       -1,120.43
# 26    RCSL3   14,100        4.01             0.00    0.00%            0.00
# 28    RCSL3   14,100        4.05             4.01    1.18%          670.86
# 21      61,224.79
# 23      57,653.63
# 24      58,188.80
# 25      57,068.44
# 26      56,564.28
# 28      57,128.46
# 27      57,003.42
# 29      55,308.87
# 30      54,334.55
# 31      55,078.79
# 32      55,762.02
# 34      52,842.07
# 33      53,178.18
# 36      52,081.82
# 35      51,927.77
# 37      51,681.69
# 38      51,851.74
# 40      51,997.79
# 39      52,381.92
# 41      52,722.03
# 42      50,589.33
# 44      51,105.50
# 43      50,736.38
# 45      51,051.48
# 46      50,709.37
# 48      47,804.43
# 47      48,448.64
# 49      48,956.80
# 50      48,655.71
# 52      27,703.90
# 53      14,209.51
# 54      28,059.01
# 51      24,426.83
# 55      24,370.82
# 56      24,408.83
# 57      32,675.51
# 58      25,093.05
# 59      56,840.37
# 61      54,699.67
# 60      54,322.55
# 63      56,495.25
# 62      57,143.46
# 64      57,823.69
# 65      59,682.29
# 66      66,638.55
# 67      66,726.58
# 69      67,761.91
# 68      66,666.56
# 70      59,919.37
# 71       7,872.46
# 72      10,083.17
# 73      71,750.21
# 74      73,724.85
# 75      74,128.98
# 77      74,699.17
# 76      76,409.72
# 78      71,047.98
# 79       7,482.33
# 80      79,560.75
# 82      80,525.06
# 81      77,562.10
# 83      67,902.96
# 84      67,968.98
# 85      69,235.39
# 86      70,107.68
# 88      71,495.13
# 87      71,043.98
# 89      68,403.12
# 90      67,004.67
# 92      67,736.91
# 91      67,514.83
# 94      68,731.23
# 93      68,024.00
# 95      67,344.78
# 96      68,887.28
# 97      70,139.69
# 98      69,982.64
# 100     71,428.10
# 99      70,662.86
# 101     72,788.55
# 102     73,174.67
# 104     71,641.17
# 103     70,702.87
# 105     67,126.71
# 107     64,564.88
# 106     63,958.68
# 108     67,218.74
# 109      5,960.84
# 110     61,854.99
# 111     68,877.28
# 113     70,767.89
# 112     73,332.72
# 114     74,411.07
# 115     72,448.44
# 117     69,962.63
# 116     70,527.81
# 118     64,039.70
# 119     63,246.45
# 121     64,901.98
# 120     65,026.03
# 122     66,026.35
# 123     66,256.42
# 125     15,495.93
# 126     47,174.23
# 124     62,125.08
# 127     63,835.64
# 128     66,146.39
# 130     67,666.88
# 129     62,125.08
# 131     58,703.97
# 132     59,102.10
# 134     59,644.28
# 133     59,304.17
# 137     50,637.35
# 138     59,152.12
# 135      8,807.76
# 136     50,181.20
# 139      8,887.79
# 140     61,969.03
# 141     63,037.38
# 142     62,665.26
# 144     63,100.40
# 143     64,747.93
# 145     64,471.84
# 146     64,395.82
# 147     64,805.95
# 148     63,322.47
# 150     63,863.65
# 149     65,663.23
# 151     66,378.46
# 152     66,578.53
# 154     24,050.71
# 155     41,286.31
# 153     64,573.88
# 156     65,063.04
# 157     67,026.67
# 159     67,526.84
# 158     67,306.77
# 161     68,002.99
# 160     70,107.68
# 162     71,836.24
# 163     68,227.06
# 164     68,667.21
# 165     68,502.15
# 167     68,917.29
# 166     66,938.65
# 168     67,676.89
# 169     67,491.83
# 170     68,006.99
# 171     70,062.66
# 173     70,545.82
# 172     66,836.61
# 174     67,346.78
# 175     67,601.86
# 177     68,277.08
# 176     68,292.09
# 179     68,403.12
# 178     70,118.68
# 181     70,645.85
# 180     70,604.84
# 182     70,604.84
# 183     71,027.97
# 185     11,804.73
# 186     57,784.67
# 184     68,957.30
# 188     71,218.04
# 187     69,107.35
# 189     69,811.58
# 190     69,648.53
# 192     69,165.37
# 191     68,823.26
# 193     63,907.66
# 194     63,825.63
# 196     64,375.81
# 195     64,095.72
# 197     64,525.86
# 198     64,825.96
# 200     65,366.14
# 199     66,581.53
# 202     59,694.29
# 201     61,345.83
# 204     61,983.04
# 203     53,440.26
# 205     53,995.44
# 206     59,706.30
# 207     28,229.07
# 208     31,659.18
# 209     59,694.29
# 211     59,898.36
# 210     60,140.44
# 213     57,251.50
# 212     53,137.16
# 214     53,404.25
# 217     17,541.60
# 215     34,716.18
# 216     17,358.54
# 218     35,076.29
# 219     32,379.42
# 220     21,587.91
# 222     53,557.30
# 221     51,636.67
# 223     52,170.85
# 224     48,409.63
# 225     48,907.79
# 226     47,630.37
# 227     48,140.54
# 228     48,990.82
# 230     49,655.03
# 229     48,275.58
# 231     48,776.75
# 232     49,833.09
# 234     50,337.25
# 233     49,235.89
# 235     47,111.20
# 236     48,044.51
# 238     48,044.51
# 237     57,161.47
# 239     57,696.64
# 240     58,048.76
# 241     58,048.76
# 242     59,272.16
# 243     57,983.74
# 244     57,623.62
# 246     55,823.04
# 245     56,863.37
# 247     56,863.37
# 248     60,084.42
# 249     20,719.63
# 250     35,152.32
# 251     54,945.75
# 253      5,264.61
# 254     51,201.53
# 252     52,815.06
# 255     53,339.23
# 256     53,397.25
# 258     53,397.25
# 257     52,672.01

# %%
fig, ax = plt.subplots(1, figsize=(20, 5))
ax.grid()
fig.autofmt_xdate()
plt.xticks(rotation=70)
plt.subplots_adjust(bottom=0.20)
plt.bar(dfFinal[dfFinal.columns.values[0]], dfFinal[dfFinal.columns.values[7]])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1999.9499999999998">

# %% [markdown]
# ## Resultado

# %%
df_tot_mes_format
# Out:
# <style type="text/css">
# #T_6ba25_row0_col1, #T_6ba25_row0_col2, #T_6ba25_row0_col3, #T_6ba25_row1_col1, #T_6ba25_row1_col2, #T_6ba25_row1_col3, #T_6ba25_row2_col3, #T_6ba25_row3_col1, #T_6ba25_row3_col2, #T_6ba25_row3_col3, #T_6ba25_row4_col1, #T_6ba25_row4_col2, #T_6ba25_row4_col3, #T_6ba25_row5_col2, #T_6ba25_row5_col3, #T_6ba25_row6_col3, #T_6ba25_row7_col1, #T_6ba25_row7_col2, #T_6ba25_row7_col3 {
#   color: green;
# }
# #T_6ba25_row0_col4, #T_6ba25_row1_col4, #T_6ba25_row2_col1, #T_6ba25_row2_col2, #T_6ba25_row2_col4, #T_6ba25_row3_col4, #T_6ba25_row4_col4, #T_6ba25_row5_col1, #T_6ba25_row5_col4, #T_6ba25_row6_col1, #T_6ba25_row6_col2, #T_6ba25_row6_col4, #T_6ba25_row7_col4 {
#   color: red;
# }
# </style>
# <table id="T_6ba25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ba25_level0_col0" class="col_heading level0 col0" >Mês</th>
#       <th id="T_6ba25_level0_col1" class="col_heading level0 col1" >Resultado (R$)</th>
#       <th id="T_6ba25_level0_col2" class="col_heading level0 col2" >Porcentagem</th>
#       <th id="T_6ba25_level0_col3" class="col_heading level0 col3" >Total Lucros</th>
#       <th id="T_6ba25_level0_col4" class="col_heading level0 col4" >Total Perdas</th>
#       <th id="T_6ba25_level0_col5" class="col_heading level0 col5" >Qt Lucros</th>
#       <th id="T_6ba25_level0_col6" class="col_heading level0 col6" >Qt Perdas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mes</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ba25_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6ba25_row0_col0" class="data row0 col0" >January</td>
#       <td id="T_6ba25_row0_col1" class="data row0 col1" >2,491.73</td>
#       <td id="T_6ba25_row0_col2" class="data row0 col2" >7.59%</td>
#       <td id="T_6ba25_row0_col3" class="data row0 col3" >14,312.75</td>
#       <td id="T_6ba25_row0_col4" class="data row0 col4" >-11,821.02</td>
#       <td id="T_6ba25_row0_col5" class="data row0 col5" >11</td>
#       <td id="T_6ba25_row0_col6" class="data row0 col6" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6ba25_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6ba25_row1_col0" class="data row1 col0" >February</td>
#       <td id="T_6ba25_row1_col1" class="data row1 col1" >7,090.31</td>
#       <td id="T_6ba25_row1_col2" class="data row1 col2" >88.95%</td>
#       <td id="T_6ba25_row1_col3" class="data row1 col3" >35,530.94</td>
#       <td id="T_6ba25_row1_col4" class="data row1 col4" >-28,440.63</td>
#       <td id="T_6ba25_row1_col5" class="data row1 col5" >12</td>
#       <td id="T_6ba25_row1_col6" class="data row1 col6" >7</td>
#     </tr>
#     <tr>
#       <th id="T_6ba25_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6ba25_row2_col0" class="data row2 col0" >March</td>
#       <td id="T_6ba25_row2_col1" class="data row2 col1" >-5,854.89</td>
#       <td id="T_6ba25_row2_col2" class="data row2 col2" >-15.25%</td>
#       <td id="T_6ba25_row2_col3" class="data row2 col3" >17,381.07</td>
#       <td id="T_6ba25_row2_col4" class="data row2 col4" >-23,235.96</td>
#       <td id="T_6ba25_row2_col5" class="data row2 col5" >11</td>
#       <td id="T_6ba25_row2_col6" class="data row2 col6" >7</td>
#     </tr>
#     <tr>
#       <th id="T_6ba25_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6ba25_row3_col0" class="data row3 col0" >April</td>
#       <td id="T_6ba25_row3_col1" class="data row3 col1" >1,475.46</td>
#       <td id="T_6ba25_row3_col2" class="data row3 col2" >3.46%</td>
#       <td id="T_6ba25_row3_col3" class="data row3 col3" >23,772.11</td>
#       <td id="T_6ba25_row3_col4" class="data row3 col4" >-22,296.65</td>
#       <td id="T_6ba25_row3_col5" class="data row3 col5" >15</td>
#       <td id="T_6ba25_row3_col6" class="data row3 col6" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6ba25_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6ba25_row4_col0" class="data row4 col0" >May</td>
#       <td id="T_6ba25_row4_col1" class="data row4 col1" >7,813.69</td>
#       <td id="T_6ba25_row4_col2" class="data row4 col2" >9.90%</td>
#       <td id="T_6ba25_row4_col3" class="data row4 col3" >15,710.66</td>
#       <td id="T_6ba25_row4_col4" class="data row4 col4" >-7,896.97</td>
#       <td id="T_6ba25_row4_col5" class="data row4 col5" >17</td>
#       <td id="T_6ba25_row4_col6" class="data row4 col6" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6ba25_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6ba25_row5_col0" class="data row5 col0" >June</td>
#       <td id="T_6ba25_row5_col1" class="data row5 col1" >-926.04</td>
#       <td id="T_6ba25_row5_col2" class="data row5 col2" >2.24%</td>
#       <td id="T_6ba25_row5_col3" class="data row5 col3" >8,853.70</td>
#       <td id="T_6ba25_row5_col4" class="data row5 col4" >-9,779.74</td>
#       <td id="T_6ba25_row5_col5" class="data row5 col5" >16</td>
#       <td id="T_6ba25_row5_col6" class="data row5 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6ba25_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6ba25_row6_col0" class="data row6 col0" >July</td>
#       <td id="T_6ba25_row6_col1" class="data row6 col1" >-3,009.12</td>
#       <td id="T_6ba25_row6_col2" class="data row6 col2" >-2.41%</td>
#       <td id="T_6ba25_row6_col3" class="data row6 col3" >4,832.73</td>
#       <td id="T_6ba25_row6_col4" class="data row6 col4" >-7,841.85</td>
#       <td id="T_6ba25_row6_col5" class="data row6 col5" >8</td>
#       <td id="T_6ba25_row6_col6" class="data row6 col6" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6ba25_level0_row7" class="row_heading level0 row7" >Total</th>
#       <td id="T_6ba25_row7_col0" class="data row7 col0" >Ano</td>
#       <td id="T_6ba25_row7_col1" class="data row7 col1" >9,081.14</td>
#       <td id="T_6ba25_row7_col2" class="data row7 col2" >94.48%</td>
#       <td id="T_6ba25_row7_col3" class="data row7 col3" >120,393.96</td>
#       <td id="T_6ba25_row7_col4" class="data row7 col4" >-111,312.82</td>
#       <td id="T_6ba25_row7_col5" class="data row7 col5" >90</td>
#       <td id="T_6ba25_row7_col6" class="data row7 col6" >42</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### ======================================== TESTES ========================================

# %%
bla
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 bla
#
# NameError: name 'bla' is not defined

# %% [markdown]
# from subprocess import Popen
# p = Popen("Executa.bat", cwd=r"C:\Users\esmer\Desktop\Alexandre\Projeto Git\StockManager")
# stdout, stderr = p.communicate()

# %%
example = {'Team':['Australia', 'England', 'South Africa',
                   'Australia', 'England', 'India', 'India',
                        'South Africa', 'England', 'India'],
                          
           'Player':['Ricky Ponting', 'Joe Root', 'Hashim Amla',
                     'David Warner', 'Jos Buttler', 'Virat Kohli',
                     'Rohit Sharma', 'David Miller', 'Eoin Morgan',
                                                 'Dinesh Karthik'],
                                                   
          'Runs':[345, 336, 689, 490, 989, 672, 560, 455, 342, 376],
            
          'Salary':[34500, 33600, 68900, 49000, 98899,
                    67562, 56760, 45675, 34542, 31176] }
  
dfa = pd.DataFrame(example)

# %%
dfa

# %%
total_salary = dfa.groupby(['Team', 'Runs']).mean('Salary')

# %%
total_salary

# %%
df_agg = dfFinal.loc[dfFinal['Data da Operação'] > '2021-11-01']
df_agg

# %%
df_agg.loc('2021-11-03':'2021-11-10', 'Data da Operação')

# %%
df_agg.groupby(['Data da Operação', 'Tipo Operação', 'Ativo']) \
              .agg(teste1 = ('%', 'mean'), teste2 = ('Lucro/Perda (R$)', 'mean')) \
              .sort_values(['Data da Operação', 'Tipo Operação'], ascending=[True, False])

# %%
df_teste = dfFinal.loc[dfFinal['Data da Operação'] > '2023-01-15'].groupby(['Data da Operação', 'Tipo Operação']).sum(['Lucro/Perda (R$)', 'Valor Compra'])

# %%
del df_teste['Preço (R$)']
del df_teste['%']

# %%
df_teste['%'] = (df_teste['Lucro/Perda (R$)'] * 100) / df_teste['Valor Compra']

# %%
df_teste
